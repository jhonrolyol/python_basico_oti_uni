# %%
# Esto es un comentario

# Comentemos
# varias
# lineas de
# codigo python

# No olvidar que siempre es recomendable comentar
# el codigo muy bien

# %%
# Declarar / definir variables

x = True
y = 1
nombre = "Abraham Zamudio"
complejo1 = 3+6j

# %%
# Definamos otras variables
edad = 42
peso = 103
estatura = 1.82
apellidoPaterno = "Zamudio"
apellidoMaterno = "Chauca"
opt1 = False
cm2 = 0.5 + 3.1415j

# %%
# Algunas caracteristricas de python

# Python es un lenguaje de programacion interpretado
# Python es un lenguaje de programacion de tipado dinamico
edad = "old"

# Python es en lenguaje eminentemente orientado a objetos

# %%
# Funcion type
type(cm2)
# Out:
# complex

# %%
# tipo de dato
type(apellidoPaterno)
# Out:
# str

# %%
# tipo de dato
type(opt1)
# Out:
# bool

# %%
# python es un lenguaje de tipado dinamico
opt1 = 3.14
type(opt1)
# Out:
# float

# %%
# Que tipo de dato es actualmente la variable edad
type(edad)
# Out:
# str

# %%
# Dato de tipo punto flotante
# El punto decimal se puede mover
# 2/10 = 0.2
# 0.25*10 = 2.5
# float : (parte entera).(parte decimal o mantisa)

# https://www.geeksforgeeks.org/ieee-standard-754-floating-point-numbers/
# https://en.wikipedia.org/wiki/IEEE_754
# https://www.jldelafuenteoconnor.es/Libro98_ful_portada.pdf
  # Apendice B. ERRORES DE REDONDEO Y ARITM ´ ETICA DE PRECISION FINITA

# %%
# Fechas
fecha1 = "22/07/2024"
fecha2 = "22 de julio del 2024"

# %%
type(fecha1)
# Out:
# str

# %%
#
x = None

# %%
x

# %%
X1 = "cuarenta y dos"
x1 = 42

# %%
type(x1)
# Out:
# int

# %%
type(X1)
# Out:
# str

# %%
# Declaracion de variables variables en una misma linea
c1,c2,c3 = 12, 0.5, "PrimeraClase"

# %%
c1
# Out:
# 12

# %%
c3
# Out:
# 'PrimeraClase'
