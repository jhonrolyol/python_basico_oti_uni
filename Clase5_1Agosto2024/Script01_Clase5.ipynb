# %%
# La estructura de decision if puede estar acompañada de uno o varios elif
# Ademas, puede estar acompañada de un else

# La indentacion marca la dependencia de una sentencia

# %%
# La estructura de repeticion for, tiene una naturaleza conjuntista

# for indice in iterable :
  # sentencia1
  # sentencia2

# iterables : str y range

# %% [markdown]
# # La estructura de repeticion while

# %%
contador = 0
while contador <10:
  print("python" + "\tValor actual de contador " + str(contador))
  # Actualizamos el valor de la variable contador
  # nueva valor de contador = antiguo valor de contador + 2
  contador = contador + 2
  # la anterior linea es "absolutamente necesaria", pues si no actualizamos la variable contador
  # la expresion booleana que evalua la estructura de repeticion while nunca llegaria a ser False
# Out:
# python	Valor actual de contador 0
# python	Valor actual de contador 2
# python	Valor actual de contador 4
# python	Valor actual de contador 6
# python	Valor actual de contador 8

# %%
contador
# Out:
# 10

# %%
# Considere el escenario donde el valor de actualizacion es un aleatorio

# Importamos el modulo random
import random as rnd

Numveces = 0
NumIter = 0
while Numveces < 20:
  NumIter = NumIter + 1
  print("Python " + "Numero de veces " + str(Numveces))
  # actualicemos Numveces con un aleatorio
  Numveces = Numveces + (rnd.randint(0,20))

print("Numero de iteraciones ", NumIter)
# Out:
# Python Numero de veces 0
# Python Numero de veces 1.0837983867343681
# Python Numero de veces 2.1999215607682725
# Python Numero de veces 3.316044734802177
# Python Numero de veces 4.471527907565983
# Python Numero de veces 5.6331142572075255
# Python Numero de veces 6.74268372927537
# Python Numero de veces 6.74268372927537
# Python Numero de veces 7.777948653116748
# Python Numero de veces 8.91900318920057
# Python Numero de veces 10.071188797029674
# Python Numero de veces 11.198567001187506
# Python Numero de veces 12.343564565831095
# Python Numero de veces 13.343564565831095
# Python Numero de veces 13.343564565831095
# Python Numero de veces 14.427362952565463
# Python Numero de veces 15.549381406867427
# Python Numero de veces 16.704864579631234
# Python Numero de veces 17.866450929272776
# Python Numero de veces 19.011448493916365
# Numero de iteraciones  20

# %%
# Pidamos al usuario un numero diferente de cero
# Si ingresa cero debe de pedir nuevamente el numero
#
# UPDATE al requerimiento : Solo puede equivocar 3 veces consecutivas


# Pidamos una primera vez la variable numero
numero = int(input("Ingresa un numero diferente de cero "))

# Definamos un contador de veces
NumVezError = 0

while numero == 0:
  numero = int(input("Ingresa un numero diferente de cero "))
  # Actualizar un contador de veces
  NumVezError = NumVezError +1
  if NumVezError == 2 :
    # Esta asignacion logra que el while sea False : Concluyendo asi el while
    numero = 666
    print("Se te acabaron los intentos.")
# Out:
# Ingresa un numero diferente de cero 12

# %%
# Ingresar un conjunto no determinado de notas y calcular el promedio
# El valor 999 indica el fin del ingreso de notas

nota = float(input("Ingrese una nota : "))

if nota != 999:
  # Variable acumuladora
  suma = nota

  # Variable contadora
  n = 1

  while nota != 999 :
    nota = float(input("Ingrese una nota : "))
    if nota != 999:
      suma =  suma + nota
      n = n + 1

  print("El promedio de notas ingresadas es : %.3f" %(suma / n))
else:
  print("No se ingresaron notas .")
# Out:
# Ingrese una nota : 0
# Ingrese una nota : 0
# Ingrese una nota : 1
# Ingrese una nota : 999
# El promedio de notas ingresadas es : 0.333

# %% [markdown]
# # La estructura match

# %%
# match parametro:
#   case valor1:
#     sentencia1
#     sentencia2
#   case valor2:
#     sentencia3
#     sentencia4
#   case _:
#     sentencia_por_defecto
# Out:
# Python 3.10.12

# %%
# pidamos un numero al usuario
num = int(input("ingresa un numero : "))

match num:
  case 1:
    print("I")
  case 2:
    print("II")
  case 3:
    print("III")
  case _:
    print("NO es 1 , 2 o 3")
# Out:
# ingresa un numero : 12
# NO es 1 , 2 o 3

# %%
#
nombre = input("Ingresa  tu nombre : ")

match nombre:
  case "Abraham"|"abraham":
    print("Usuario existente")
  case "Elon"|"elon":
    print("Usuario Administrador")
  case "Anderson"|"anderson":
    print("Programador Senior")
  case _:
    print("Usuario Inexistente")
# Out:
# Ingresa  tu nombre : Abraham
# Usuario existente

# %%
#
lado_a = float(input("Ingresa el primer lado del triangulo"))

match lado_a:
  case lado_a if lado_a>0:
    print("positivo")
  case lado_a if lado_a<0:
    print("negativo")
  case _:
    print("Cero")
# Out:
# Ingresa el primer lado del triangulo15
# positivo

# %%
# Ciclo 20061
# Ciclo 20122

semestre = input("Ingresa el semestre a analizar ")

match semestre[-1]:
  case "1":
    print("Esta en el primer semestre del año")
  case "2":
    print("Esta en el segundo semestre del año")
  case _:
    print("Caso no contemplado")
# Out:
# Ingresa el semestre a analizar 20245
# Caso no contemplado
